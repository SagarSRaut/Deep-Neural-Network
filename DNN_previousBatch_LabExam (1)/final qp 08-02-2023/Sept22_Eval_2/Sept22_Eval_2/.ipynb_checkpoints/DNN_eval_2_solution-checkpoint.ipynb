# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# **PRN**:                  ______________________________<br>
# **Name of Student**:      ______________________________<br>
# **Date of Submission**:   ______________________________<br>

# %% [markdown]
# # Deep Neural Networks
# ## PG-DAI September  2022
#
#
# # Evaluation 2

# %% [markdown]
# ## Instruction:
# <div class="alert alert-block alert-warning" style="font-family: Arial; font-size:1.2em;">
#    <b>Follow these instructions carefully.</b>
#        <li>Your code shall be free of any compilation error. If your code fails in compilation, your submission will be <b><i>rejected</i></b>.</li>
#        <li>Put comments to explain your code. Explain your steps in details.</li>
#        <li>Do not <b>REMOVE</b> any cell.If you delete any cell, your submission may become invalid.</li>
#        <li>Your code shall be within the lines marked for the purpose.</li>
#        <li>Upload the file to the designated location by renaming as <strong>PRN_{PRN # last 3 digits}_DNN_Eval_Assignment_1.ipynb</strong></li>
#     </ol>
#     <b>Important:</b>Your code shall be between lines marked thus.
# </div>
#
# >`#### START YOUR CODE`
# > Feel free to add cell
#
# >`#### END YOUR CODE`

# %% [markdown]
# ## 1. Import Statements
# **Task 1:** Import all the libraries you may need for successful execution of your code.**(2 marks)**

# %%
#### START YOUR CODE
# Lets import some libraries
import os

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %matplotlib inline

#### END YOUR CODE

# %% [markdown]
# ## 2. Hyper-Parameters and others
#
# **Task 2:** Declare Hyper-Parameters.**(3 marks)**
#
# **Note:** Declaration of Hyper-Parameters else where should be avoided.

# %%
#### START YOUR CODE
# Some basic parameters
inpDir = '../../input'
outDir = '../output'
subDir = 'personality classification'

RANDOM_STATE = 24

np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 10 # number of epochs
ALPHA = 0.1 # learning rate
NOISE = 0.2 # Noise to be introduced in the data
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

#### END YOUR CODE

# %% [markdown]
# ## Helper Function
# Following helper function is given for your convenience. Feel free to modify as deemed fit.

# %%
def fn_plot_hist(hist_df):
    
    # Instantiate plt object with 1 row two columns
    fig, axes = plt.subplots(1,2 , figsize = (15,6)) 

    # Propertiesfor matplotlib.patch.Patch 
    props = dict(boxstyle='round', 
                 facecolor='aqua', 
                 alpha=0.4)

    ax = axes[0]

    # plot loss columns of the dataframe
    hist_df.plot(y = ['loss','val_loss'], ax = ax, colormap=CMAP)

    # Mark min loss and min val_loss
    lossmin = hist_df['loss'].min()
    testmin = hist_df['val_loss'].min()

    # Little beautification
    txtstr = "Min Loss: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(lossmin,
                                                                            testmin) #text to plot

    # Place a text box in upper left in axis coords
    ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    # set labels on the axes
    ax.set_xlabel("Epochs")

    ax.set_ylabel("Loss")

    # show grid
    ax.grid();

    # for second figure
    ax = axes[1]

    # plot accuracy and val_accuracy
    hist_df.plot( y = ['accuracy', 'val_accuracy'], ax = ax, colormap=CMAP)
    

    # get max accuracies
    accmax = hist_df['accuracy'].max()
    testmax = hist_df['val_accuracy'].max()
    
    # Little beautification
    txtstr = "Max Accuracy: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(accmax,
                                                                                testmax) #text to plot

    # place a text box in upper left in axis coords
    ax.text(0.4, 0.5, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    # Mark labels
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Accuracy")
    
    # Show grid
    ax.grid();
    
    # Organise subplot params so that the subplots fit in to the figure area
    plt.tight_layout()

# %% [markdown]
# ## Dataset Information:
#
# This dataset is for classification of personalities in following categories
# ESTJ - The Supervisor
# ENTJ - The Commander
# ESFJ - The Provider
# ENFJ - The Giver
# ISTJ - The Inspector
# ISFJ - The Nurturer
# INTJ - The Mastermind
# INFJ - The Counselor
# ESTP - The Doer
# ESFP - The Performer
# ENTP - The Visionary
# ENFP - The Champion
# ISTP - The Craftsman
# ISFP - The Composer
# INTP - The Thinker
# INFP - The Idealist
#
# Mapping followed in the dataset is
#
# 0	ESTJ
# 1	ENTJ
# 2	ESFJ
# 3	ENFJ
# 4	ISTJ
# 5	ISFJ
# 6	INTJ
# 7	INFJ
# 8	ESTP
# 9	ESFP
# 10	ENTP
# 11	ENFP
# 12	ISTP
# 13	ISFP
# 14	INTP
# 15	INFP

# %% [markdown]
# ## Load Data
# **Task 3:** Load data provided in `16P.csv`. **(5 marks)**
#
# **Note:**
# 1. Use of any **other** dataset will make this submission **invalid**.
# 2. The information provided in this Notebook is sufficient to enter column names.
# 3. You may also use `16p-Mapping.txt` file for data description.

# %%
#### START YOUR CODE
df = pd.read_csv(os.path.join(inpDir, subDir, '16P.csv'))
df.head()
#### END YOUR CODE
# Out:
#    Response Id  You regularly make new friends.  \
# 0            0                                0
# 1            1                                0
# 2            2                                0
# 3            3                                0
# 4            4                                0
#
#    You spend a lot of your free time exploring various random topics that pique your interest  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                 -1
# 4                                                  0
#
#    Seeing other people cry can easily make you feel like you want to cry too  \
# 0                                                  0
# 1                                                 -2
# 2                                                  2
# 3                                                  3
# 4                                                 -1
#
#    You often make a backup plan for a backup plan.  \
# 0                                                0
# 1                                               -3
# 2                                                0
# 3                                               -1
# 4                                                0
#
#    You usually stay calm, even under a lot of pressure  \
# 0                                                  0
# 1                                                 -1
# 2                                                 -1
# 3                                                  0
# 4                                                  2
#
#    At social events, you rarely try to introduce yourself to new people and mostly talk to the ones you already know  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                 -1
#
#    You prefer to completely finish one project before starting another.  \
# 0                                                  1
# 1                                                 -2
# 2                                                  0
# 3                                                 -2
# 4                                                 -2
#
#    You are very sentimental.  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
#
#    You like to use organizing tools like schedules and lists.  ...  \
# 0                                                  0           ...
# 1                                                  3           ...
# 2                                                  1           ...
# 3                                                 -2           ...
# 4                                                  1           ...
#
#    You believe that pondering abstract philosophical questions is a waste of time.  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    You feel more drawn to places with busy, bustling atmospheres than quiet, intimate places.  \
# 0                                                  0
# 1                                                 -2
# 2                                                  2
# 3                                                  0
# 4                                                  1
#
#    You know at first glance how someone is feeling.  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                -1
# 4                                                 0
#
#    You often feel overwhelmed.  \
# 0                           -1
# 1                            2
# 2                            2
# 3                           -1
# 4                            2
#
#    You complete things methodically without skipping over any steps.  \
# 0                                                  0
# 1                                                  0
# 2                                                 -1
# 3                                                  0
# 4                                                  0
#
#    You are very intrigued by things labeled as controversial.  \
# 0                                                  0
# 1                                                 -1
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#    You would pass along a good opportunity if you thought someone else needed it more.  \
# 0                                                  0
# 1                                                 -1
# 2                                                  1
# 3                                                  0
# 4                                                 -1
#
#    You struggle with deadlines.  \
# 0                             0
# 1                            -1
# 2                             2
# 3                            -2
# 4                             2
#
#    You feel confident that things will work out for you.  Personality
# 0                                                  0             ENFP
# 1                                                  3             ISFP
# 2                                                  1             INFJ
# 3                                                 -1             ISTP
# 4                                                 -1             ENFJ
#
# [5 rows x 62 columns]

# %%
len(df.Personality.unique())
77/2
# Out:
# 38.5

# %% [markdown]
# ## Train and Test Sets
# **Task 4**: Prepare train and test sets from the data, namely - X_test, X_train,  y_train, y_test **(5 marks)**

# %%
#### START YOUR CODE
y = df['Personality'].to_numpy()
X = df.drop('Personality', axis =1).to_numpy()

#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y,
                                                    test_size=TEST_SIZE,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)


'''sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)'''

le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)

#### END YOUR CODE
# Out:
# (47999, 61) (47999,) (12000, 61) (12000,)

# %% [markdown]
# ## Declare your model
#
# **Task 5:**
# 1. Specify kernel initializer.
# 2. Prepare model using Sequential class of TensorFlow with one Hidden Layer and one output layer
#
# $
# \begin{align}
# Marks = \left\{
# \begin{array}{cl}
# \text{for Specify kernel initializer}&= 2\\
# \text{for preparing model appropriately}&= 3.\\
# \end{array}
# \right.
# \end{align}
# $

# %%
#### START YOUR CODE
krnl_init = tf.keras.initializers.GlorotUniform(
                                   seed=RANDOM_STATE
                                   )

# Define sequential model with same size and activation functions
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(38, activation='tanh', kernel_initializer=krnl_init),
  tf.keras.layers.Dense(16, kernel_initializer=krnl_init)
])

# Using cross entropy for loss calculations
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

#### END YOUR CODE
# Out:
# 2022-12-27 11:47:14.252795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.277365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.277549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.278400: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-27 11:47:14.279042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.279176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.279288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.588495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.588657: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.588810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-27 11:47:14.588911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4128 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## Compile and Fit your model
#
# **Task 6:**
# 1. Plot loss and accuracy curves for both testing and training. **(5 marks)**

# %%
#### START YOUR CODE

model.compile(optimizer='Adam',
              loss=loss_fn,
              metrics=['accuracy'])
              
history = model.fit(X_train, y_train ,
                    validation_data = [X_test, y_test],
                    epochs = EPOCHS, verbose =2)
res_df = pd.DataFrame(history.history)
fn_plot_hist(res_df)
#### END YOUR CODE
# Out:
# Epoch 1/10
# 2022-12-27 11:47:15.407289: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1500/1500 - 2s - loss: 2.7846 - accuracy: 0.0617 - val_loss: 2.7806 - val_accuracy: 0.0626 - 2s/epoch - 1ms/step
# Epoch 2/10
# 1500/1500 - 1s - loss: 2.7802 - accuracy: 0.0625 - val_loss: 2.7752 - val_accuracy: 0.0626 - 1s/epoch - 880us/step
# Epoch 3/10
# 1500/1500 - 1s - loss: 2.7823 - accuracy: 0.0620 - val_loss: 2.8114 - val_accuracy: 0.0628 - 1s/epoch - 850us/step
# Epoch 4/10
# 1500/1500 - 1s - loss: 2.7819 - accuracy: 0.0657 - val_loss: 2.7756 - val_accuracy: 0.0632 - 1s/epoch - 859us/step
# Epoch 5/10
# 1500/1500 - 1s - loss: 2.7782 - accuracy: 0.0613 - val_loss: 2.7754 - val_accuracy: 0.0637 - 1s/epoch - 854us/step
# Epoch 6/10
# 1500/1500 - 1s - loss: 2.7767 - accuracy: 0.0634 - val_loss: 2.7747 - val_accuracy: 0.0644 - 1s/epoch - 858us/step
# Epoch 7/10
# 1500/1500 - 1s - loss: 2.7788 - accuracy: 0.0638 - val_loss: 2.7753 - val_accuracy: 0.0638 - 1s/epoch - 856us/step
# Epoch 8/10
# 1500/1500 - 1s - loss: 2.7794 - accuracy: 0.0654 - val_loss: 2.7983 - val_accuracy: 0.0640 - 1s/epoch - 853us/step
# Epoch 9/10
# 1500/1500 - 1s - loss: 2.7794 - accuracy: 0.0636 - val_loss: 2.7770 - val_accuracy: 0.0649 - 1s/epoch - 855us/step
# Epoch 10/10
# 1500/1500 - 1s - loss: 2.7788 - accuracy: 0.0674 - val_loss: 2.7728 - val_accuracy: 0.0647 - 1s/epoch - 855us/step

# %% [markdown]
# ## Summary of analysis
#
# **Task 7:**
# 1. Comment on loss curve. Is data provided  sufficient to train the model? Comment from the perspective of under-fitting/over-fitting.**(5 marks)**
# 2. Have you used any data transformation such as Scaler etc.? Please Explain. **(10 marks)**

# %%
#Explanation Task 7.1

# %%
#Explanation Task 7.2

# %% [markdown]
# ## Reinforcement Learning
#
# **Task 8:**
# 1. Explain difference between state-value-function and action-value-function.**(5 marks)**

# %% [markdown]
# **Explanation Task 8** : The state-value-function returns the value of achieving a certain state and the action-value-function returns the value for choosing an action in a state, whereas a value means the total amount of rewards until reaching terminal state.
